# %% [markdown]
# # Nivelacion Informatica - 2025

# %% [markdown]
# Consta de dos partes, una __teorica__ que debe entregar COMPLETA el día de la nivelación y una __práctica__ que se dara a conocer en ese mismo dia y debe desarrollarla en el aula en ese momento

# %% [markdown]
# # Parte I: teórica

# %% [markdown]
# Debe realizar el siguiente trabajo a mano en hojas aparte de bloc o de examen, las preguntas están divididas en cuatro secciones, debe escribir el nombre de la sección y las respuestas correspondiente a la misma:

# %% [markdown]
# ### Seccion 1: Concepto de funciones estadisticas

# %% [markdown]
# 1. Sobre las funciones estadisticas de Excel indique:
#
# - Que son
# - Donde se encuentran
# - Cual es su uso fundamental
#
# 2. Defina las siguientes funciones estadisticas
#
# - Suma
# - Max
# - Min
# - Contar.si
# - Promedio
# - Promedio.si
# - Moda.si
# - Sumar.si
#
# 3. Sobre la función `promedio.si` consulte:
# - Sintaxis
# - Nombre cada una de sus partes y definalas
# - Escriba un ejemplo de la vida real donde se pueda emplear esta funcion
#
# 4. Sobre la funcion `sumar.si` consulte:
# - Sintaxis
# - Nombre cada una de sus partes y definalas
# - Escriba un ejemplo de la vida real donde se pueda emplear esta funcion

# %% [markdown]
# ### Sección 2: Concepto de funciones logicas y formato condicional

# %% [markdown]
# 1. Sobre las funciones logicas de EXCEL indique:
#
# - Que son
# - donde se encuentran
# - nombre las funciones logicas
#
# 2. Sobre la funcion logica `SI` escriba:
#
# - Cuales son sus características
# - Que usos tiene
# - Describa su sintaxis
# - Nombre sus partes.
#
# 3. Sobre la funcion logica **verdadero de Excel, consulte:**
#
# - Concepto
# - Sintaxis
# - Mencione un ejemplo
#
# 4. Sobre la funcion logica falso **de Excel, consulte:**
#
# - Concepto
# - Sintaxis
# - Mencione un ejemplo
#
# 5. Defina los siguientes operadors logicos:
#
# - AND
# - OR
# - NOT

# %% [markdown]
# ### Sección 3: Estructura de HTML

# %% [markdown]
# 1. Sobre HTML indique:
#
# - que es
# - sus caracteristicas
# - sus usos
#
# 2. Sobre la estructura de un documento web html indique:
#
# - sus partes
# - Escriba las etiquetas o tags basicas
# - Realice un ejemplo
#
# 3. Defina la funcion de las siguientes etiquetas HTML
#
# - head
# - body
# - title
# - head
# - p
# - br
#
# 4. Explique como se crea una lista ordenada
#
# 5. Explique como se crea una lista sin ordenar
#
# 6. Sobre VS code indique:
#
# - Concepto
# - Caracteristicas
# - Usos
#
# 7. Realice el dibujo o esquema del arbol del DOM
# 8. Sobre el DOM consulte:
#
# - Concepto
# - Aplicaciones
# - Importancia
# - Atributos
#
# 9. Sobre las etiquetas Meta, indique:
#
# - concepto
# - cual es su utilidad
# - que importancia tienen
# - nombre al menos 3 etiquetas meta mas usuales
#
# 10. Indique que etiquetas se usan en HTML para:
# - Negrita
# - Cursiva
# - Subrayado
# - Tachado
#
# 11. Indique como se crean un enlace a otro sitio web:
# - Que se abra en la misma pagina
# - Que se abra en una pagina diferente
#
# 12. INdique como se crean los siguientes enlaces en HTML:
# - Correo electronico
# - A una seccion de la misma pagina

# %% [markdown]
# ### Sección 4: Diseño web CSS

# %% [markdown]
# 1. Sobre CSS consulte:
# - Concepto
# - Caracterisiticas
# - Ventajas y desventajas
# - Nombre tres formas de incluir CSS en  una pagina web desde el paradigma de Vanila Design
# - Nombre tres frameworks de css mas empleados actualmente
#
# 2. Sobre la sintaxis css indique:
# - Caracteristicas
# - Que son los selectores
# - Nombre los tipos de selectores
#
# 3. Indique que es CSS header
# 4. Explique que son los selectores universales.
#
# 5. Sobre las tablas HTML consulte:
# - Que etiquetas se usan para crearlas
# - Que reglas se deben tener en cuenta para su creación
# - Escriba el código de una tabla sencilla
#
# 6. Indique la función de los siguientes atributos o etiquetas HTML
# - Colspan
# - Rowspan
#
# 7. Explique como se puede asignar color a una tablas HTML
# 8. Indique cual es la diferencia entre `th` y `td`
#
# 9. Sobre la etiqueta `<div>` consulte:
# - Concepto
# - Cuales son sus principales usos
# - En que se diferencia con <table>
# - Importancia
#
# 10. Consulte en que consiste  la maquetacion web
#
# 11. Explique que otros elementos pueden emplearse como contenedores aparte de la etiqueta <div>
#
# 12. Nombre al menos 10 propiedades de estilo que se puedan aplicar a la etiqueta DIV
