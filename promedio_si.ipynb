# %% [markdown]
# <h1>Tabla de contenido<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Asignatura-Informatica---Grado-10" data-toc-modified-id="Asignatura-Informatica---Grado-10-0.0.1"><span class="toc-item-num">0.0.1&nbsp;&nbsp;</span>Asignatura Informatica - Grado 10</a></span></li></ul></li></ul></li><li><span><a href="#Funcion-PROMEDIO.SI" data-toc-modified-id="Funcion-PROMEDIO.SI-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Funcion PROMEDIO.SI</a></span><ul class="toc-item"><li><span><a href="#Concepto" data-toc-modified-id="Concepto-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Concepto</a></span></li><li><span><a href="#Estructura" data-toc-modified-id="Estructura-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Estructura</a></span><ul class="toc-item"><li><span><a href="#Rango" data-toc-modified-id="Rango-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Rango</a></span></li><li><span><a href="#Criterio" data-toc-modified-id="Criterio-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Criterio</a></span></li><li><span><a href="#Rango-promedio" data-toc-modified-id="Rango-promedio-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Rango promedio</a></span></li></ul></li><li><span><a href="#Problema" data-toc-modified-id="Problema-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Problema</a></span></li><li><span><a href="#Analisis-del-Problema" data-toc-modified-id="Analisis-del-Problema-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Analisis del Problema</a></span><ul class="toc-item"><li><span><a href="#Identificando-los-tres-campos" data-toc-modified-id="Identificando-los-tres-campos-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Identificando los tres campos</a></span></li></ul></li><li><span><a href="#Preparando-las-celdas-para-los-resultados" data-toc-modified-id="Preparando-las-celdas-para-los-resultados-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Preparando las celdas para los resultados</a></span></li><li><span><a href="#Insertando-la-funcion-PROMEDIO.SI" data-toc-modified-id="Insertando-la-funcion-PROMEDIO.SI-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Insertando la funcion PROMEDIO.SI</a></span></li><li><span><a href="#Verificando-los-resultados" data-toc-modified-id="Verificando-los-resultados-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Verificando los resultados</a></span></li><li><span><a href="#Complete-el-ejemplo" data-toc-modified-id="Complete-el-ejemplo-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Complete el ejemplo</a></span></li></ul></li><li><span><a href="#Ejercicio-1" data-toc-modified-id="Ejercicio-1-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Ejercicio 1</a></span><ul class="toc-item"><li><span><a href="#Desarrolle" data-toc-modified-id="Desarrolle-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Desarrolle</a></span></li></ul></li><li><span><a href="#Ejercicio-2" data-toc-modified-id="Ejercicio-2-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Ejercicio 2</a></span><ul class="toc-item"><li><span><a href="#Desarrolle" data-toc-modified-id="Desarrolle-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Desarrolle</a></span></li></ul></li></ul></div>

# %% [markdown]
# ### Asignatura Informatica - Grado 10
# __Clase:__ Funcion condicionada: PROMEDIO.SI <br>
# __Profesor:Alexander Acevedo Gomez__<br>
# Ingeniero de Sistemas - Universidad Nacional de Colombia <br>
# Magister en Modelado y Simulacion por Computador - Universidad Jorge Tadeo Lozano <br>
# __Telegram: @Alex6m__

# %% [markdown]
# # Funcion PROMEDIO.SI
# ## Concepto
# > La funcion promedio.si hace parte del grupo de _funciones condicionadas_, donde su caracteristica principal es el uso de un campo sujeto a una condicion, la mayoria de veces estas se resuelven usando los operadores relacionales:
# >
# > | Operador       | Signo | Definicion |
# |----------------|-------|------------|
# | Mayor que      | >     | A > B      |
# | Menor que      | <     | A < B      |
# | Igual a        | =     | A = B      |
# | No es igual a  | <>    | A <> B     |
# >
# > Aclaracion: el uso de la sintaxis de estos operadores es verificada en Excel, puede variar en otros software o lenguaje de programacion.
# ## Estructura
# > Consta de tres campos:
# >
# > ### Rango
# >> Corresponde a la columna de datos que contienen la condicion para ser relacionada en el calculo del promedio.
# > ### Criterio
# >> Es la condicion a evaluar, dentro de los datos de la columna _Rango_.
# > ### Rango promedio
# >> Corresponde a la columna de datos donde se desea calcular el promedio. Generalmente es diferente a la columna rango, puede darse el caso en donde los tres campos pertenecen a la misma columna.

# %% [markdown]
# ## Problema
# > Dada la siguiente tabla, halle el promedio de distancia en kilometros de las ciudades con salida al mar
# > - Seleccione y Copie la tabla (control-c o clic derecho copiar) y peguela en la Hoja 1 de Excel (control-v o clic derecho pegar)
# >
# > | Distancia   entre ciudades | Kilómetros | Millas | Salida al mar |
# |----------------------------|------------|--------|---------------|
# | Cali                       | 300        | 187    | No            |
# | Medellín                   | 245        | 152    | No            |
# | Barranquilla               | 707        | 440    | Si            |
# | Cartagena de Indias        | 660        | 410    | Si            |
# | Cúcuta                     | 403        | 250    | No            |
# | Bucaramanga                | 298        | 185    | No            |
# | Pereira                    | 181        | 112    | No            |
# | Santa Marta                | 733        | 456    | Si            |
# | Ibagué                     | 129        | 80     | No            |
# | Bello                      | 252        | 156    | No            |
# | Pasto                      | 517        | 321    | No            |
# | Manizales                  | 167        | 104    | No            |

# %% [markdown]
# ## Analisis del Problema
# > ### Identificando los tres campos
# >> AL leer el enunciado se tiene claro lo siguiente:
# >> - El promedio a calcular corresponde a la distancia en Kilometros - Columna B y corresponderia al campo __Rango promedio__.
# >> - Ahora se debe identificar la columna donde se encuentra la condicion a la cual estan sujetos los datos, segun el enunciado se debe tener en cuenta solamente las ciudades con salida al mar, la columna que proporciona esta informacion es la D, por lo tanto seria el campo __Rango__.
# >> - Por ultimo, se define la condicion, recordemos que esta debe pertenecer a la misma columna del campo _Rango_, interesan unicamente las ciudades con salida al mar, dicha informacion se indica en la tabla con la palabra _Si_, al ser un texto el operador a usar es _igual a_ y la sintaxis final es: ="Si". Dicha expresion corresponde al __Criterio__.
# >>
# >> __Nota:__ Tenga en cuenta que en caso de ser texto, la expresion en el campo _Criterio_ debe ir entre comillas y estar escrita exactamente igual a como aparece en la tabla, ya que Excel es Case Sensitive.
# >>
# >> La siguiente imagen indica la correspondencia entre columnas y campos para este problema:
# >>
# >> ![promedio.png](attachment:promedio.png)

# %% [markdown]
# ## Preparando las celdas para los resultados
# > - En la celda E1 escriba: Promedios a calcular
# > - En la celda F1 escriba: Resultados
# > - Celda E2: Distancia en Kms Salida al mar
#
# ## Insertando la funcion PROMEDIO.SI
# > - Ubiquese en la celda F2
# > - Dirijase al simbolo $\varSigma$, luego haga clic en _Mas funciones_
# > - En la nueva ventana seleccione la categoria _Estadisticas_.
# > - Dentro del listado busque: __promedio.si__ y haga clic en Aceptar
# > - Ingrese los datos segun lo explicado en la seccion 2.2.1
# >
# ## Verificando los resultados
# > Si ingreso los datos correctamente, el promedio de la distancia de ciudades con salida al mar es 700
# >
# ## Complete el ejemplo
# > Debajo, de los anteriores datos calcule:
# > - Promedio de distancia en Kms de las ciudades sin salida al mar
# > - Promedio de distancia en Millas de las ciudades con salida al mar
# > - Promedio de distancia en MIllas de las ciudades que no tienen salida al mar
# >
# > Conteste en su cuaderno las siguientes preguntas:
# > - Que caracteristica en comun tienen los campos _Rango_ y _criterio_?
# > - Si el criterio corresponde a un texto, cual operador relacional se debe usar? Por que ?
# > - Segun lo leido hasta el momento que entiende por _Case Sensitive_?

# %% [markdown]
# # Ejercicio 1
# Los siguientes datos corresponden a los departamentos mas grandes de Colombia (en superficie) y su comparacion aproximada con otros paises. Copielos en la hoja 2 (Control-v):
# >
# >| N.º | Departamento | Capital               | País similar en superficie | Superficie (km²) |
# |-----|--------------|-----------------------|----------------------------|------------------|
# | 1   | Amazonas     | Leticia               | Bulgaria                   | 109.665          |
# | 2   | Vichada      | Puerto Carreño        | Corea del Sur              | 100.242          |
# | 3   | Caquetá      | Florencia             | Azerbayan                  | 88.965           |
# | 4   | Meta         | Villavicencio         | Austria                    | 85.635           |
# | 5   | Guainía      | Inírida               | Sierra Leona               | 72.238           |
# | 6   | Antioquia    | Medellín              | Togo                       | 63.612           |
# | 7   | Vaupés       | Mitú                  | Croacia                    | 54.135           |
# | 8   | Guaviare     | San José del Guaviare | Croacia                    | 53.460           |
# | 9   | Chocó        | Quibdó                | República Dominicana       | 46.530           |
# | 10  | Casanare     | Yopal                 | Dinamarca                  | 44.640           |
# | 11  | Nariño       | Pasto                 | Moldavia                   | 33.268           |
# | 12  | Santander    | Bucaramanga           | Bélgica                    | 30.537           |
# | 13  | Cauca        | Popayán               | Lesoto                     | 29.308           |
# | 14  | Bolívar      | Cartagena             | Macedonia del norte        | 25.978           |
# | 15  | Córdoba      | Montería              | Macedonia del norte        | 25.020           |
# | 16  | Putumayo     | Mocoa                 | Yibuti                     | 24.885           |
# | 17  | Arauca       | Arauca                | Yibuti                     | 23.818           |
# | 18  | Tolima       | Ibagué                | Yibuti                     | 23.562           |
# | 19  | Boyacá       | Tunja                 | Yibuti                     | 23.189           |
# | 20  | Magdalena    | Santa Marta           | Yibuti                     | 23.188           |
# >
# ## Desarrolle
# > Calcule en las columnas contiguas:
# >
# > 1. El promedio de extension de los departamentos cuya superficie es similar a __Yibuti__.
# > 2. El promedio de extension de los departamentos cuya superficie es similar a __Croacia__.
# > 3. El promedio de los departamentos cuya extension es superior a 40.000 Kms.
# > 4. El promedio de los departamentos cuya extension es inferior a 40.000 Kms.

# %% [markdown]
# # Ejercicio 2
# La siguiente tabla corresponde a las islas mas grandes del mundo segun su poblacion y el pais al cual pertenecen, Copie la siguiente tabla en la hoja 3 de su archivo (seleccionela clic derecho copiar  control-c):
# >
# > | Island        | Countries                   | Population  | Area (km²) | People per km² |
# |---------------|-----------------------------|-------------|------------|----------------|
# | Java          | Indonesia                   | 141,000,000 | 138793     | 1015.9         |
# | Bali          | Indonesia                   | 4,225,000   | 5780       | 731            |
# | Taiwan        | Taiwan                      | 23,571,000  | 36193      | 651.3          |
# | Zealand       | Denmark                     | 3,749,200   | 7031       | 533.2          |
# | Luzon         | Philippines                 | 53,336,134  | 109965     | 485            |
# | Honshu        | Japan                       | 104,000,000 | 227960     | 456.2          |
# | Panay         | Philippines                 | 4,477,247   | 12011      | 372.8          |
# | Kyushu        | Japan                       | 12,970,479  | 36753      | 352.9          |
# | Puerto Rico   | United   States             | 3,195,000   | 9104       | 350.9          |
# | Negros        | Philippines                 | 4,414,131   | 13310      | 331.6          |
# | Sri Lanka     | Sri Lanka                   | 21,440,000  | 65,610     | 326.8          |
# | Great Britain | United   Kingdom            | 66,040,000  | 209331     | 315.5          |
# | Hispaniola    | Dominican   Republic, Haiti | 21,396,000  | 76,192     | 280.8          |
# | Jamaica       | Caribbean                   | 2,890,000   | 10992      | 262.9          |
# | Mindanao      | Philippines                 | 25,537,691  | 97530      | 261.8          |
# | Hainan        | China                       | 8,670,000   | 33,920     | 255.6          |
# | Shikoku       | Japan                       | 3,845,534   | 18800      | 204.5          |
# | Sicily        | Italy                       | 5,057,000   | 25711      | 196.7          |
# | Flores        | Indonesia                   | 1,831,000   | 13540      | 135.2          |
# | Samar         | Philippines                 | 1,751,267   | 13429      | 130.4          |
# >
# ## Desarrolle
# > 1. Calcule el promedio de poblacion por Km2 (People Km2) de las islas que pertenecen a Philippines.
# > 2. El promedio de Area de los paises cuya Poblacion por Km2 (People Km2) es superior a 300 Kms.
# > 3. El promedio de Poblacion (Population) de los paises que pertenecen a Indonesia.
# > 4. El promedio de Poblacion (Population) de los paises cuya area es inferior a 30000
